# %%
import ast
import datetime

import cpi
import matplotlib.pyplot as plt
# Required imports
import numpy as np
import pandas as pd
import seaborn as sns
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
# Common functions

# Source: https://stackoverflow.com/questions/43214978/seaborn-barplot-displaying-values
def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center")
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

dict_columns = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

def text_to_dict(df):
    for column in dict_columns:
        df[column] = df[column].apply(lambda x: {} if pd.isna(x) else ast.literal_eval(x) )
    return df

def plot_itemset(title, result, dataset_size, rotation=90):
    plt.figure(figsize=(20,12))
    sns.barplot([", ".join(list(x)) for x in result["itemsets"]], [x * dataset_size for x in result["support"]])
    plt.xticks(fontsize=12,rotation=rotation)
    plt.title(title,fontsize=20)
    plt.show()

def fix_date(date):
    x = pd.to_datetime(date, format="%m/%d/%y")
    if x.year > 2020:
        year = x.year - 100
    else:
        year = x.year
    return datetime.datetime(year,x.month,x.day)

def adjust_price_to_inflation(price, date):
    return int(cpi.inflate(price, date.year))

# %%
# Datasets loading
dataset_original = pd.read_csv('./tmdb-box-office-prediction/train.csv')
dataset = dataset_original

oscars = pd.read_csv('./tmdb-box-office-prediction/the_oscar_award.csv')
oscars_winners = oscars[oscars["winner"] == True].drop(columns=["winner", "year_film", "year_ceremony", "ceremony", "category", "name"])
oscars_winners = oscars_winners[oscars_winners["film"].notnull()]
dataset_lc = dataset.copy()
oscars_winners_lc = oscars_winners.copy()
dataset_lc['title'] = dataset_lc['title'].str.lower()
oscars_winners_lc['film'] = oscars_winners_lc['film'].str.lower()
oscar_movies = pd.merge(left=dataset_lc, right=oscars_winners_lc, left_on='title', right_on='film').drop_duplicates(subset='id')
oscar_movies = oscar_movies.drop(columns=['film'])

dataset = text_to_dict(dataset)
dataset["release_date"] = dataset["release_date"].apply(fix_date)
dataset["budget"] = dataset.apply(lambda x: adjust_price_to_inflation(x["budget"], x["release_date"]), axis=1)
dataset["revenue"] = dataset.apply(lambda x: adjust_price_to_inflation(x["revenue"], x["release_date"]), axis=1)

oscar_movies = text_to_dict(oscar_movies)
oscar_movies["release_date"] = oscar_movies["release_date"].apply(fix_date)
oscar_movies["budget"] = oscar_movies.apply(lambda x: adjust_price_to_inflation(x["budget"], x["release_date"]), axis=1)
oscar_movies["revenue"] = oscar_movies.apply(lambda x: adjust_price_to_inflation(x["revenue"], x["release_date"]), axis=1)

# %%
print(dataset.info())
print(dataset.describe(include=[np.number]))
dataset.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  3000 non-null   object
#  2   budget                 3000 non-null   int64
#  3   genres                 3000 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   3000 non-null   object
#  12  production_countries   3000 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       3000 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               3000 non-null   object
#  20  cast                   3000 non-null   object
#  21  crew                   3000 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(17)
# memory usage: 539.2+ KB
# None
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  3.186236e+07     8.463274   107.856571  1.027183e+08
# std     866.169729  4.686381e+07    12.104000    22.086434  1.963601e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  3.829557e+06
# 50%    1500.500000  1.373169e+07     7.374861   104.000000  2.865800e+07
# 75%    2250.250000  4.263318e+07    10.890983   118.000000  1.096155e+08
# max    3000.000000  4.318934e+08   294.337037   338.000000  2.541059e+09
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  15101018
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  54135944
# 2   3                                                 {}   3563750
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0   2015-02-20    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   2004-08-06   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2   2014-10-10   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
#
#                                                 crew    revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...   13283126
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  128775114
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   14138371
#
# [3 rows x 23 columns]

# %%
feature_vector = ['budget', 'genres', 'homepage', 'belongs_to_collection', 'original_language', 'release_date', 'production_companies', 'production_countries', 'runtime', 'Keywords', 'cast', 'crew', 'revenue']
dataset[feature_vector].head(5)
# Out:
#      budget                                             genres  \
# 0  15101018                     [{'id': 35, 'name': 'Comedy'}]
# 1  54135944  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3563750                      [{'id': 18, 'name': 'Drama'}]
# 3   1336221  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage  \
# 0                                NaN
# 1                                NaN
# 2  http://sonyclassics.com/whiplash/
# 3         http://kahaanithefilm.com/
# 4                                NaN
#
#                                belongs_to_collection original_language  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...                en
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...                en
# 2                                                 {}                en
# 3                                                 {}                hi
# 4                                                 {}                ko
#
#   release_date                               production_companies  \
# 0   2015-02-20  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1   2004-08-06        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2   2014-10-10  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3   2012-03-09                                                 {}
# 4   2009-02-05                                                 {}
#
#                                 production_countries  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...    113.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...    105.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]    118.0
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 {}
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew    revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...   13283126
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  128775114
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   14138371
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...   17816284
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...    4676071

# %%
# Data mappers
def check_belongs_to_collection(element):
    return (isinstance(element,list) or isinstance(element,dict)) and len(element) > 0
    
def map_belongs_to_collection(dataset):    
    return dataset['belongs_to_collection'].apply(lambda x: check_belongs_to_collection(x))
    
def check_has_homepage(element):
    return isinstance(element, str) and element.startswith(('http:', 'https:'))
    
def map_has_homepage(dataset):    
    return dataset['homepage'].apply(lambda x: check_has_homepage(x))

def map_release_date_to_release_month(dataset):
    return dataset['release_date'].apply(lambda x: x.month)

def map_runtime(dataset):
    return dataset['runtime'].apply(lambda x: int(x))

def check_production_company(element):
    return (isinstance(element,list) or isinstance(element,dict)) and len(element) > 0
    
def check_production_country(element):
    return (isinstance(element,list) or isinstance(element,dict)) and len(element) > 0

def check_keywords(element):
    return (isinstance(element,list) or isinstance(element,dict)) and len(element) > 0

def check_genres(element):
    return (isinstance(element,list) or isinstance(element,dict)) and len(element) > 0

# %%
processed_dataset = dataset.copy()
feature_vector = ['budget', 'genres', 'homepage', 'belongs_to_collection', 'original_language', 'release_date', 'production_companies', 'production_countries', 'runtime', 'Keywords', 'cast', 'crew', 'revenue']
processed_dataset = processed_dataset[feature_vector]
processed_dataset = processed_dataset[processed_dataset['budget'] != 0]
processed_dataset['belongs_to_collection'] = map_belongs_to_collection(processed_dataset)
processed_dataset['homepage'] = map_has_homepage(processed_dataset)
processed_dataset['release_date'] = map_release_date_to_release_month(processed_dataset)
processed_dataset = processed_dataset.rename(columns={'release_date': 'release_month'})
processed_dataset = processed_dataset[processed_dataset['runtime'].notnull()]
processed_dataset['runtime'] = map_runtime(processed_dataset)
#keywordsMask = processed_dataset['Keywords'].apply(lambda x: check_keywords(x))
#processed_dataset = processed_dataset[keywordsMask]
#companiesMask = processed_dataset['production_companies'].apply(lambda x: check_production_company(x))
#processed_dataset = processed_dataset[companiesMask]
#countriesMask = processed_dataset['production_countries'].apply(lambda x: check_production_country(x))
#processed_dataset = processed_dataset[countriesMask]
# genresMask = processed_dataset['genres'].apply(lambda x: check_genres(x))
# processed_dataset = processed_dataset[genresMask]

processed_dataset['genres'] = processed_dataset['genres'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
processed_dataset['production_companies'] = processed_dataset['production_companies'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
processed_dataset['production_countries'] = processed_dataset['production_countries'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
processed_dataset['Keywords'] = processed_dataset['Keywords'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
processed_dataset['cast'] = processed_dataset['cast'].apply(lambda x: [i['name'] for i in x] if x != {} else [])
processed_dataset['crew'] = processed_dataset['crew'].apply(lambda x: [i['name'] for i in x if i['job'] == 'Director'] if x != {} else [])
processed_dataset = processed_dataset.rename(columns={'crew': 'directors'})
processed_dataset = processed_dataset.rename(columns={'Keywords': 'keywords'})
processed_dataset = processed_dataset.reset_index(drop=True)

processed_dataset['production_companies_sizes'] = processed_dataset['production_companies'].apply(lambda x: len(x))
processed_dataset['production_countries_sizes'] = processed_dataset['production_countries'].apply(lambda x: len(x))
processed_dataset['keywords_sizes'] = processed_dataset['keywords'].apply(lambda x: len(x))
processed_dataset['cast_sizes'] = processed_dataset['cast'].apply(lambda x: len(x))
processed_dataset['director_sizes'] = processed_dataset['directors'].apply(lambda x: len(x))

processed_dataset
# Out:
#          budget                                       genres  homepage  \
# 0      15101018                                     [Comedy]     False
# 1      54135944             [Comedy, Drama, Family, Romance]     False
# 2       3563750                                      [Drama]      True
# 3       1336221                            [Thriller, Drama]      True
# 4      18004014               [Animation, Adventure, Family]     False
# ...         ...                                          ...       ...
# 2182   16978824  [Action, Adventure, Drama, Family, Fantasy]     False
# 2183   81203917                              [Comedy, Drama]      True
# 2184  105912715           [Crime, Action, Mystery, Thriller]     False
# 2185   56842742                            [Comedy, Romance]      True
# 2186   39779651                  [Thriller, Action, Mystery]      True
#
#       belongs_to_collection original_language  release_month  \
# 0                      True                en              2
# 1                      True                en              8
# 2                     False                en             10
# 3                     False                hi              3
# 4                     False                en              8
# ...                     ...               ...            ...
# 2182                  False                en              3
# 2183                  False                en              6
# 2184                  False                en             10
# 2185                  False                en              1
# 2186                  False                en              9
#
#                                    production_companies  \
# 0     [Paramount Pictures, United Artists, Metro-Gol...
# 1                                [Walt Disney Pictures]
# 2     [Bold Films, Blumhouse Productions, Right of W...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2182                       [Douglas Fairbanks Pictures]
# 2183  [DreamWorks SKG, Amblin Entertainment, Parkes/...
# 2184  [New Line Cinema, Forge, The Steve Tisch Company]
# 2185                 [Jersey Films, Loofah Productions]
# 2186  [Lions Gate Films, Vertigo Entertainment, Goth...
#
#             production_countries  runtime  \
# 0     [United States of America]       93
# 1     [United States of America]      113
# 2     [United States of America]      105
# 3                        [India]      122
# 4                             []       83
# ...                          ...      ...
# 2182  [United States of America]      149
# 2183  [United States of America]      128
# 2184  [United States of America]      120
# 2185  [United States of America]       90
# 2186  [United States of America]      106
#
#                                                keywords  \
# 0     [time travel, sequel, hot tub, duringcreditsst...
# 1         [coronation, duty, marriage, falling in love]
# 2     [jazz, obsession, conservatory, music teacher,...
# 3     [mystery, bollywood, police corruption, crime,...
# 4                                                    []
# ...                                                 ...
# 2182  [male nudity, treasure, magic, palace, flying ...
# 2183  [new york, airport, marriage proposal, transla...
# 2184  [assassination, amnesia, hostage, chase, dark ...
# 2185  [beach, honeymoon, bride, chance, risk, relati...
# 2186  [cia, airport, hero, fight, kidnapping, time b...
#
#                                                    cast           directors  \
# 0     [Rob Corddry, Craig Robinson, Clark Duke, Adam...        [Steve Pink]
# 1     [Anne Hathaway, Julie Andrews, Héctor Elizond...    [Garry Marshall]
# 2     [Miles Teller, J.K. Simmons, Melissa Benoist, ...   [Damien Chazelle]
# 3     [Vidya Balan, Nawazuddin Siddiqui, Parambrata ...       [Sujoy Ghosh]
# 4     [Scott Grimes, Tom Bosley, Rickie Lee Jones, J...    [Hal Sutherland]
# ...                                                 ...                 ...
# 2182  [Douglas Fairbanks, Snitz Edwards, Charles Bel...       [Raoul Walsh]
# 2183  [Tom Hanks, Catherine Zeta-Jones, Stanley Tucc...  [Steven Spielberg]
# 2184  [Geena Davis, Samuel L. Jackson, Yvonne Zima, ...      [Renny Harlin]
# 2185  [Ben Stiller, Jennifer Aniston, Philip Seymour...      [John Hamburg]
# 2186  [Taylor Lautner, Lily Collins, Alfred Molina, ...    [John Singleton]
#
#         revenue  production_companies_sizes  production_countries_sizes  \
# 0      13283126                           3                           1
# 1     128775114                           1                           1
# 2      14138371                           3                           1
# 3      17816284                           0                           1
# 4       7340322                           0                           0
# ...         ...                         ...                         ...
# 2182   18148357                           1                           1
# 2183  296959010                           3                           1
# 2184  145763206                           3                           1
# 2185  232735009                           2                           1
# 2186   93297097                           6                           1
#
#       keywords_sizes  cast_sizes  director_sizes
# 0                  4          24               1
# 1                  4          20               1
# 2                 12          51               1
# 3                  7           7               1
# 4                  0           4               1
# ...              ...         ...             ...
# 2182              12          21               1
# 2183              18          23               1
# 2184              14          15               1
# 2185              22          26               1
# 2186              14          34               1
#
# [2187 rows x 18 columns]

# %%
r = processed_dataset.sort_values('revenue', ascending=False)["cast"].head(500)
r = r.reset_index(drop=True).tolist()
te = TransactionEncoder()
te_ary = te.fit(r).transform(r)
df = pd.DataFrame(te_ary, columns=te.columns_)
res = fpgrowth(df, min_support=0.0015, max_len=3, use_colnames=True)
a = res[res["itemsets"].str.len() >= 2].sort_values('support', ascending=False).reset_index(drop=True).head(50)
a
# Out:
#     support                                           itemsets
# 0     0.012                   (Lois Maxwell, Desmond Llewelyn)
# 1     0.008                          (Peter Cullen, Mark Ryan)
# 2     0.008   (Geoffrey Keen, Walter Gotell, Desmond Llewelyn)
# 3     0.008                         (Chris Wedge, Denis Leary)
# 4     0.008                        (Reno Wilson, Jess Harnell)
# 5     0.008                       (Reno Wilson, John Turturro)
# 6     0.008                     (Reno Wilson, Glenn Morshower)
# 7     0.008                        (Reno Wilson, Peter Cullen)
# 8     0.008                        (Reno Wilson, Josh Duhamel)
# 9     0.008                           (Reno Wilson, Mark Ryan)
# 10    0.008                      (Cheech Marin, Tony Shalhoub)
# 11    0.008        (Pierce Brosnan, Samantha Bond, Judi Dench)
# 12    0.008                        (Samantha Bond, Judi Dench)
# 13    0.008             (Reno Wilson, Josh Duhamel, Mark Ryan)
# 14    0.008                    (Pierce Brosnan, Samantha Bond)
# 15    0.008                  (Geoffrey Keen, Desmond Llewelyn)
# 16    0.008                     (Geoffrey Keen, Walter Gotell)
# 17    0.008                  (Walter Gotell, Desmond Llewelyn)
# 18    0.008                       (Pierce Brosnan, Judi Dench)
# 19    0.008                      (John Leguizamo, Denis Leary)
# 20    0.008                            (Stan Lee, Chris Evans)
# 21    0.008                    (Christopher Lee, Ian McKellen)
# 22    0.008                      (Chris Wedge, John Leguizamo)
# 23    0.008          (Reno Wilson, Peter Cullen, Josh Duhamel)
# 24    0.008                        (Hugo Weaving, Elijah Wood)
# 25    0.008          (Reno Wilson, Jess Harnell, Peter Cullen)
# 26    0.008      (Jess Harnell, Peter Cullen, Glenn Morshower)
# 27    0.008          (Chris Wedge, John Leguizamo, Ray Romano)
# 28    0.008          (John Leguizamo, Ray Romano, Denis Leary)
# 29    0.008             (Chris Wedge, Ray Romano, Denis Leary)
# 30    0.008                       (John Leguizamo, Ray Romano)
# 31    0.008                          (Ray Romano, Denis Leary)
# 32    0.008                          (Chris Wedge, Ray Romano)
# 33    0.008             (Reno Wilson, Jess Harnell, Mark Ryan)
# 34    0.008          (Reno Wilson, Jess Harnell, Josh Duhamel)
# 35    0.008       (Reno Wilson, Jess Harnell, Glenn Morshower)
# 36    0.008             (Reno Wilson, Peter Cullen, Mark Ryan)
# 37    0.008         (Reno Wilson, John Turturro, Jess Harnell)
# 38    0.008            (Reno Wilson, John Turturro, Mark Ryan)
# 39    0.008         (Reno Wilson, John Turturro, Josh Duhamel)
# 40    0.008         (Reno Wilson, John Turturro, Peter Cullen)
# 41    0.008      (Reno Wilson, John Turturro, Glenn Morshower)
# 42    0.008          (Reno Wilson, Glenn Morshower, Mark Ryan)
# 43    0.008         (Chris Wedge, John Leguizamo, Denis Leary)
# 44    0.008       (Reno Wilson, Glenn Morshower, Josh Duhamel)
# 45    0.008       (Reno Wilson, Peter Cullen, Glenn Morshower)
# 46    0.008     (Tony Burton, Talia Shire, Sylvester Stallone)
# 47    0.008  (Tony Burton, Sylvester Stallone, Burgess Mere...
# 48    0.008     (John Turturro, Peter Cullen, Glenn Morshower)
# 49    0.008                    (Patrick Stewart, Hugh Jackman)

# %%
itemset_names = {}
for index, item in enumerate(a.itemsets):
    itemset_names[item] = "actor_itemset_" + str(index)
itemset_names
# Out:
# {frozenset({'Desmond Llewelyn', 'Lois Maxwell'}): 'actor_itemset_0',
#  frozenset({'Mark Ryan', 'Peter Cullen'}): 'actor_itemset_1',
#  frozenset({'Desmond Llewelyn',
#             'Geoffrey Keen',
#             'Walter Gotell'}): 'actor_itemset_2',
#  frozenset({'Chris Wedge', 'Denis Leary'}): 'actor_itemset_3',
#  frozenset({'Jess Harnell', 'Reno Wilson'}): 'actor_itemset_4',
#  frozenset({'John Turturro', 'Reno Wilson'}): 'actor_itemset_5',
#  frozenset({'Glenn Morshower', 'Reno Wilson'}): 'actor_itemset_6',
#  frozenset({'Peter Cullen', 'Reno Wilson'}): 'actor_itemset_7',
#  frozenset({'Josh Duhamel', 'Reno Wilson'}): 'actor_itemset_8',
#  frozenset({'Mark Ryan', 'Reno Wilson'}): 'actor_itemset_9',
#  frozenset({'Cheech Marin', 'Tony Shalhoub'}): 'actor_itemset_10',
#  frozenset({'Judi Dench',
#             'Pierce Brosnan',
#             'Samantha Bond'}): 'actor_itemset_11',
#  frozenset({'Judi Dench', 'Samantha Bond'}): 'actor_itemset_12',
#  frozenset({'Josh Duhamel', 'Mark Ryan', 'Reno Wilson'}): 'actor_itemset_13',
#  frozenset({'Pierce Brosnan', 'Samantha Bond'}): 'actor_itemset_14',
#  frozenset({'Desmond Llewelyn', 'Geoffrey Keen'}): 'actor_itemset_15',
#  frozenset({'Geoffrey Keen', 'Walter Gotell'}): 'actor_itemset_16',
#  frozenset({'Desmond Llewelyn', 'Walter Gotell'}): 'actor_itemset_17',
#  frozenset({'Judi Dench', 'Pierce Brosnan'}): 'actor_itemset_18',
#  frozenset({'Denis Leary', 'John Leguizamo'}): 'actor_itemset_19',
#  frozenset({'Chris Evans', 'Stan Lee'}): 'actor_itemset_20',
#  frozenset({'Christopher Lee', 'Ian McKellen'}): 'actor_itemset_21',
#  frozenset({'Chris Wedge', 'John Leguizamo'}): 'actor_itemset_22',
#  frozenset({'Josh Duhamel',
#             'Peter Cullen',
#             'Reno Wilson'}): 'actor_itemset_23',
#  frozenset({'Elijah Wood', 'Hugo Weaving'}): 'actor_itemset_24',
#  frozenset({'Jess Harnell',
#             'Peter Cullen',
#             'Reno Wilson'}): 'actor_itemset_25',
#  frozenset({'Glenn Morshower',
#             'Jess Harnell',
#             'Peter Cullen'}): 'actor_itemset_26',
#  frozenset({'Chris Wedge',
#             'John Leguizamo',
#             'Ray Romano'}): 'actor_itemset_27',
#  frozenset({'Denis Leary',
#             'John Leguizamo',
#             'Ray Romano'}): 'actor_itemset_28',
#  frozenset({'Chris Wedge', 'Denis Leary', 'Ray Romano'}): 'actor_itemset_29',
#  frozenset({'John Leguizamo', 'Ray Romano'}): 'actor_itemset_30',
#  frozenset({'Denis Leary', 'Ray Romano'}): 'actor_itemset_31',
#  frozenset({'Chris Wedge', 'Ray Romano'}): 'actor_itemset_32',
#  frozenset({'Jess Harnell', 'Mark Ryan', 'Reno Wilson'}): 'actor_itemset_33',
#  frozenset({'Jess Harnell',
#             'Josh Duhamel',
#             'Reno Wilson'}): 'actor_itemset_34',
#  frozenset({'Glenn Morshower',
#             'Jess Harnell',
#             'Reno Wilson'}): 'actor_itemset_35',
#  frozenset({'Mark Ryan', 'Peter Cullen', 'Reno Wilson'}): 'actor_itemset_36',
#  frozenset({'Jess Harnell',
#             'John Turturro',
#             'Reno Wilson'}): 'actor_itemset_37',
#  frozenset({'John Turturro', 'Mark Ryan', 'Reno Wilson'}): 'actor_itemset_38',
#  frozenset({'John Turturro',
#             'Josh Duhamel',
#             'Reno Wilson'}): 'actor_itemset_39',
#  frozenset({'John Turturro',
#             'Peter Cullen',
#             'Reno Wilson'}): 'actor_itemset_40',
#  frozenset({'Glenn Morshower',
#             'John Turturro',
#             'Reno Wilson'}): 'actor_itemset_41',
#  frozenset({'Glenn Morshower',
#             'Mark Ryan',
#             'Reno Wilson'}): 'actor_itemset_42',
#  frozenset({'Chris Wedge',
#             'Denis Leary',
#             'John Leguizamo'}): 'actor_itemset_43',
#  frozenset({'Glenn Morshower',
#             'Josh Duhamel',
#             'Reno Wilson'}): 'actor_itemset_44',
#  frozenset({'Glenn Morshower',
#             'Peter Cullen',
#             'Reno Wilson'}): 'actor_itemset_45',
#  frozenset({'Sylvester Stallone',
#             'Talia Shire',
#             'Tony Burton'}): 'actor_itemset_46',
#  frozenset({'Burgess Meredith',
#             'Sylvester Stallone',
#             'Tony Burton'}): 'actor_itemset_47',
#  frozenset({'Glenn Morshower',
#             'John Turturro',
#             'Peter Cullen'}): 'actor_itemset_48',
#  frozenset({'Hugh Jackman', 'Patrick Stewart'}): 'actor_itemset_49'}

# %%
processed_dataset["actors_itemsets"] = processed_dataset["cast"].apply(lambda x: list(filter(None, [itemset_names[itemset] if all(actor in x for actor in itemset) else [] for itemset in a.itemsets])))
for x in processed_dataset['actors_itemsets']:
    print(x)
# Out:
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_46', 'actor_itemset_47']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_3', 'actor_itemset_19', 'actor_itemset_22', 'actor_itemset_27', 'actor_itemset_28', 'actor_itemset_29', 'actor_itemset_30', 'actor_itemset_31', 'actor_itemset_32', 'actor_itemset_43']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_21', 'actor_itemset_24']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_49']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_10']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_24']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_0']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_46', 'actor_itemset_47']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_21', 'actor_itemset_24']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_20']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_3', 'actor_itemset_19', 'actor_itemset_22', 'actor_itemset_27', 'actor_itemset_28', 'actor_itemset_29', 'actor_itemset_30', 'actor_itemset_31', 'actor_itemset_32', 'actor_itemset_43']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_2', 'actor_itemset_15', 'actor_itemset_16', 'actor_itemset_17']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_11', 'actor_itemset_12', 'actor_itemset_14', 'actor_itemset_18']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_0', 'actor_itemset_2', 'actor_itemset_15', 'actor_itemset_16', 'actor_itemset_17']
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_3', 'actor_itemset_19', 'actor_itemset_22', 'actor_itemset_27', 'actor_itemset_28', 'actor_itemset_29', 'actor_itemset_30', 'actor_itemset_31', 'actor_itemset_32', 'actor_itemset_43']
# []
# ['actor_itemset_20']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_1', 'actor_itemset_4', 'actor_itemset_5', 'actor_itemset_6', 'actor_itemset_7', 'actor_itemset_8', 'actor_itemset_9', 'actor_itemset_13', 'actor_itemset_23', 'actor_itemset_25', 'actor_itemset_26', 'actor_itemset_33', 'actor_itemset_34', 'actor_itemset_35', 'actor_itemset_36', 'actor_itemset_37', 'actor_itemset_38', 'actor_itemset_39', 'actor_itemset_40', 'actor_itemset_41', 'actor_itemset_42', 'actor_itemset_44', 'actor_itemset_45', 'actor_itemset_48']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_10']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_1', 'actor_itemset_4', 'actor_itemset_5', 'actor_itemset_6', 'actor_itemset_7', 'actor_itemset_8', 'actor_itemset_9', 'actor_itemset_13', 'actor_itemset_23', 'actor_itemset_25', 'actor_itemset_26', 'actor_itemset_33', 'actor_itemset_34', 'actor_itemset_35', 'actor_itemset_36', 'actor_itemset_37', 'actor_itemset_38', 'actor_itemset_39', 'actor_itemset_40', 'actor_itemset_41', 'actor_itemset_42', 'actor_itemset_44', 'actor_itemset_45', 'actor_itemset_48']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_49']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_1', 'actor_itemset_4', 'actor_itemset_5', 'actor_itemset_6', 'actor_itemset_7', 'actor_itemset_8', 'actor_itemset_9', 'actor_itemset_13', 'actor_itemset_23', 'actor_itemset_25', 'actor_itemset_26', 'actor_itemset_33', 'actor_itemset_34', 'actor_itemset_35', 'actor_itemset_36', 'actor_itemset_37', 'actor_itemset_38', 'actor_itemset_39', 'actor_itemset_40', 'actor_itemset_41', 'actor_itemset_42', 'actor_itemset_44', 'actor_itemset_45', 'actor_itemset_48']
# []
# []
# []
# ['actor_itemset_46', 'actor_itemset_47']
# []
# []
# []
# []
# []
# ['actor_itemset_11', 'actor_itemset_12', 'actor_itemset_14', 'actor_itemset_18']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_20']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_49']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_0', 'actor_itemset_2', 'actor_itemset_15', 'actor_itemset_16', 'actor_itemset_17']
# ['actor_itemset_21']
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_0', 'actor_itemset_2', 'actor_itemset_15', 'actor_itemset_16', 'actor_itemset_17']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_46', 'actor_itemset_47']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_49']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_11', 'actor_itemset_12', 'actor_itemset_14', 'actor_itemset_18']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_1', 'actor_itemset_4', 'actor_itemset_5', 'actor_itemset_6', 'actor_itemset_7', 'actor_itemset_8', 'actor_itemset_9', 'actor_itemset_13', 'actor_itemset_23', 'actor_itemset_25', 'actor_itemset_26', 'actor_itemset_33', 'actor_itemset_34', 'actor_itemset_35', 'actor_itemset_36', 'actor_itemset_37', 'actor_itemset_38', 'actor_itemset_39', 'actor_itemset_40', 'actor_itemset_41', 'actor_itemset_42', 'actor_itemset_44', 'actor_itemset_45', 'actor_itemset_48']
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_0']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_3', 'actor_itemset_19', 'actor_itemset_22', 'actor_itemset_27', 'actor_itemset_28', 'actor_itemset_29', 'actor_itemset_30', 'actor_itemset_31', 'actor_itemset_32', 'actor_itemset_43']
# []
# []
# ['actor_itemset_0']
# []
# ['actor_itemset_10']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_21', 'actor_itemset_24']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_20']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_10']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['actor_itemset_11', 'actor_itemset_12', 'actor_itemset_14', 'actor_itemset_18']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
processed_dataset['actors_itemsets'] = processed_dataset['actors_itemsets'].apply(lambda x: x if x else ['other'])
processed_dataset = processed_dataset.explode('actors_itemsets').reset_index(drop=True)
processed_dataset.shape
# Out:
# (2349, 19)

# %%
def generate_occurrence_dict(source_dataset, column_name):
    exploded_dataset = source_dataset.explode(column_name).reset_index(drop=True)
    count = exploded_dataset.groupby([column_name]).size().reset_index(name='counts')
    count_dict = {}
    
    for idx, element in enumerate(count[column_name]):
        count_dict[element] = count[count[column_name] == element]['counts'].iloc[0]
    
    return count_dict

directors_occurrence_dict = generate_occurrence_dict(processed_dataset, 'directors')
cast_occurrence_dict = generate_occurrence_dict(processed_dataset, 'cast')
keywords_occurrence_dict = generate_occurrence_dict(processed_dataset, 'keywords')
production_countries_occurrence_dict = generate_occurrence_dict(processed_dataset, 'production_countries')
production_companies_occurrence_dict = generate_occurrence_dict(processed_dataset, 'production_companies')

# %%
processed_dataset = processed_dataset.explode('directors').reset_index(drop=True)

def checkDirector(director):
    try:
        occurrence_number = directors_occurrence_dict[director]
    except:
        occurrence_number = 0
    return occurrence_number >= 8

processed_dataset['director'] = processed_dataset['directors'].apply(lambda x: x if checkDirector(x) else 'other')
processed_dataset['director'].value_counts()
# Out:
# other                 2228
# Michael Bay            100
# Carlos Saldanha         22
# John Glen               16
# Chris Wedge             12
# Galen T. Chu            10
# Steven Spielberg        10
# Peter Jackson           10
# Mike Thurmeier          10
# Clint Eastwood           9
# Martin Scorsese          8
# Martin Campbell          8
# Wes Craven               8
# Alfred Hitchcock         8
# Ron Howard               8
# Paul W.S. Anderson       8
# Brian De Palma           8
# Steven Soderbergh        8
# Name: director, dtype: int64

# %%
processed_dataset = processed_dataset.explode('genres').reset_index(drop=True)
processed_dataset = processed_dataset.rename(columns={'genres': 'genre'})
processed_dataset.shape
# Out:
# (6683, 20)

# %%
processed_dataset
# Out:
#         budget     genre  homepage  belongs_to_collection original_language  \
# 0     15101018    Comedy     False                   True                en
# 1     54135944    Comedy     False                   True                en
# 2     54135944     Drama     False                   True                en
# 3     54135944    Family     False                   True                en
# 4     54135944   Romance     False                   True                en
# ...        ...       ...       ...                    ...               ...
# 6678  56842742    Comedy      True                  False                en
# 6679  56842742   Romance      True                  False                en
# 6680  39779651  Thriller      True                  False                en
# 6681  39779651    Action      True                  False                en
# 6682  39779651   Mystery      True                  False                en
#
#       release_month                               production_companies  \
# 0                 2  [Paramount Pictures, United Artists, Metro-Gol...
# 1                 8                             [Walt Disney Pictures]
# 2                 8                             [Walt Disney Pictures]
# 3                 8                             [Walt Disney Pictures]
# 4                 8                             [Walt Disney Pictures]
# ...             ...                                                ...
# 6678              1                 [Jersey Films, Loofah Productions]
# 6679              1                 [Jersey Films, Loofah Productions]
# 6680              9  [Lions Gate Films, Vertigo Entertainment, Goth...
# 6681              9  [Lions Gate Films, Vertigo Entertainment, Goth...
# 6682              9  [Lions Gate Films, Vertigo Entertainment, Goth...
#
#             production_countries  runtime  \
# 0     [United States of America]       93
# 1     [United States of America]      113
# 2     [United States of America]      113
# 3     [United States of America]      113
# 4     [United States of America]      113
# ...                          ...      ...
# 6678  [United States of America]       90
# 6679  [United States of America]       90
# 6680  [United States of America]      106
# 6681  [United States of America]      106
# 6682  [United States of America]      106
#
#                                                keywords  \
# 0     [time travel, sequel, hot tub, duringcreditsst...
# 1         [coronation, duty, marriage, falling in love]
# 2         [coronation, duty, marriage, falling in love]
# 3         [coronation, duty, marriage, falling in love]
# 4         [coronation, duty, marriage, falling in love]
# ...                                                 ...
# 6678  [beach, honeymoon, bride, chance, risk, relati...
# 6679  [beach, honeymoon, bride, chance, risk, relati...
# 6680  [cia, airport, hero, fight, kidnapping, time b...
# 6681  [cia, airport, hero, fight, kidnapping, time b...
# 6682  [cia, airport, hero, fight, kidnapping, time b...
#
#                                                    cast       directors  \
# 0     [Rob Corddry, Craig Robinson, Clark Duke, Adam...      Steve Pink
# 1     [Anne Hathaway, Julie Andrews, Héctor Elizond...  Garry Marshall
# 2     [Anne Hathaway, Julie Andrews, Héctor Elizond...  Garry Marshall
# 3     [Anne Hathaway, Julie Andrews, Héctor Elizond...  Garry Marshall
# 4     [Anne Hathaway, Julie Andrews, Héctor Elizond...  Garry Marshall
# ...                                                 ...             ...
# 6678  [Ben Stiller, Jennifer Aniston, Philip Seymour...    John Hamburg
# 6679  [Ben Stiller, Jennifer Aniston, Philip Seymour...    John Hamburg
# 6680  [Taylor Lautner, Lily Collins, Alfred Molina, ...  John Singleton
# 6681  [Taylor Lautner, Lily Collins, Alfred Molina, ...  John Singleton
# 6682  [Taylor Lautner, Lily Collins, Alfred Molina, ...  John Singleton
#
#         revenue  production_companies_sizes  production_countries_sizes  \
# 0      13283126                           3                           1
# 1     128775114                           1                           1
# 2     128775114                           1                           1
# 3     128775114                           1                           1
# 4     128775114                           1                           1
# ...         ...                         ...                         ...
# 6678  232735009                           2                           1
# 6679  232735009                           2                           1
# 6680   93297097                           6                           1
# 6681   93297097                           6                           1
# 6682   93297097                           6                           1
#
#       keywords_sizes  cast_sizes  director_sizes actors_itemsets director
# 0                  4          24               1           other    other
# 1                  4          20               1           other    other
# 2                  4          20               1           other    other
# 3                  4          20               1           other    other
# 4                  4          20               1           other    other
# ...              ...         ...             ...             ...      ...
# 6678              22          26               1           other    other
# 6679              22          26               1           other    other
# 6680              14          34               1           other    other
# 6681              14          34               1           other    other
# 6682              14          34               1           other    other
#
# [6683 rows x 20 columns]

# %%
processed_dataset = processed_dataset.explode('production_countries').reset_index(drop=True)

def checkCountry(production_country):
    try:
        occurrence_number = production_countries_occurrence_dict[production_country]
    except:
        occurrence_number = 0
    return occurrence_number >= 50

processed_dataset['production_country'] = processed_dataset['production_countries'].apply(lambda x: x if checkCountry(x) else 'other')
processed_dataset['production_country'].value_counts()
# Out:
# United States of America    5607
# other                       1402
# United Kingdom               851
# France                       404
# Germany                      369
# Canada                       247
# India                        179
# Name: production_country, dtype: int64

# %%
processed_dataset = processed_dataset.explode('production_companies').reset_index(drop=True)

def checkCompany(production_company):
    try:
        occurrence_number = production_companies_occurrence_dict[production_company]
    except:
        occurrence_number = 0
    return occurrence_number >= 75

processed_dataset['production_company'] = processed_dataset['production_companies'].apply(lambda x: x if checkCompany(x) else 'other')
processed_dataset['production_company'].value_counts()
# Out:
# other                                     27007
# Paramount Pictures                          800
# Warner Bros.                                657
# Universal Pictures                          594
# Twentieth Century Fox Film Corporation      540
# Di Bonaventura Pictures                     342
# Columbia Pictures                           315
# Hasbro Studios                              312
# Name: production_company, dtype: int64

# %%
processed_dataset = processed_dataset.explode('keywords').reset_index(drop=True)

def checkKeywords(keyword):
    try:
        occurrence_number = keywords_occurrence_dict[keyword]
    except:
        occurrence_number = 0
    return occurrence_number >= 75

processed_dataset['keyword'] = processed_dataset['keywords'].apply(lambda x: x if checkKeywords(x) else 'other')
processed_dataset['keyword'].value_counts()
# Out:
# other                   252796
# duringcreditsstinger      3169
# transformers              1828
# murder                    1464
# based on novel            1459
# woman director            1373
# independent film           832
# Name: keyword, dtype: int64

# %%
processed_dataset = processed_dataset.explode('cast').reset_index(drop=True)

def checkCast(actor):
    try:
        occurrence_number = cast_occurrence_dict[actor]
    except:
        occurrence_number = 0
    return occurrence_number >= 20

processed_dataset['actor'] = processed_dataset['cast'].apply(lambda x: x if checkCast(x) else 'other')
processed_dataset['actor'].value_counts()
# Out:
# other                     6398907
# Hugo Weaving                19262
# Glenn Morshower             16247
# Jess Harnell                15496
# John Turturro               15130
#                            ...
# Joost Janssen                 768
# Helen Iesha Goldthorpe        768
# Krista Schaeffer              768
# Alan Pietruszewski            768
# Vincent Jerome                768
# Name: actor, Length: 222, dtype: int64

# %%
processed_dataset
# Out:
#            budget    genre  homepage  belongs_to_collection original_language  \
# 0        15101018   Comedy     False                   True                en
# 1        15101018   Comedy     False                   True                en
# 2        15101018   Comedy     False                   True                en
# 3        15101018   Comedy     False                   True                en
# 4        15101018   Comedy     False                   True                en
# ...           ...      ...       ...                    ...               ...
# 7183315  39779651  Mystery      True                  False                en
# 7183316  39779651  Mystery      True                  False                en
# 7183317  39779651  Mystery      True                  False                en
# 7183318  39779651  Mystery      True                  False                en
# 7183319  39779651  Mystery      True                  False                en
#
#          release_month     production_companies      production_countries  \
# 0                    2       Paramount Pictures  United States of America
# 1                    2       Paramount Pictures  United States of America
# 2                    2       Paramount Pictures  United States of America
# 3                    2       Paramount Pictures  United States of America
# 4                    2       Paramount Pictures  United States of America
# ...                ...                      ...                       ...
# 7183315              9  Quick Six Entertainment  United States of America
# 7183316              9  Quick Six Entertainment  United States of America
# 7183317              9  Quick Six Entertainment  United States of America
# 7183318              9  Quick Six Entertainment  United States of America
# 7183319              9  Quick Six Entertainment  United States of America
#
#          runtime     keywords  ... production_countries_sizes keywords_sizes  \
# 0             93  time travel  ...                          1              4
# 1             93  time travel  ...                          1              4
# 2             93  time travel  ...                          1              4
# 3             93  time travel  ...                          1              4
# 4             93  time travel  ...                          1              4
# ...          ...          ...  ...                        ...            ...
# 7183315      106     teenager  ...                          1             14
# 7183316      106     teenager  ...                          1             14
# 7183317      106     teenager  ...                          1             14
# 7183318      106     teenager  ...                          1             14
# 7183319      106     teenager  ...                          1             14
#
#          cast_sizes  director_sizes  actors_itemsets  director  \
# 0                24               1            other     other
# 1                24               1            other     other
# 2                24               1            other     other
# 3                24               1            other     other
# 4                24               1            other     other
# ...             ...             ...              ...       ...
# 7183315          34               1            other     other
# 7183316          34               1            other     other
# 7183317          34               1            other     other
# 7183318          34               1            other     other
# 7183319          34               1            other     other
#
#                production_country  production_company keyword  actor
# 0        United States of America  Paramount Pictures   other  other
# 1        United States of America  Paramount Pictures   other  other
# 2        United States of America  Paramount Pictures   other  other
# 3        United States of America  Paramount Pictures   other  other
# 4        United States of America  Paramount Pictures   other  other
# ...                           ...                 ...     ...    ...
# 7183315  United States of America               other   other  other
# 7183316  United States of America               other   other  other
# 7183317  United States of America               other   other  other
# 7183318  United States of America               other   other  other
# 7183319  United States of America               other   other  other
#
# [7183320 rows x 24 columns]

# %%
processed_dataset.shape
# Out:
# (7183320, 24)

# %%
feature_vector = ['budget', 'genre', 'homepage', 'belongs_to_collection', 'original_language', 'release_month', 'production_company', 'production_country', 'runtime', 'keyword', 'actor', 'director', 'actors_itemsets', 'revenue']
processed_dataset = processed_dataset[feature_vector]
processed_dataset.head(20)
# Out:
#       budget   genre  homepage  belongs_to_collection original_language  \
# 0   15101018  Comedy     False                   True                en
# 1   15101018  Comedy     False                   True                en
# 2   15101018  Comedy     False                   True                en
# 3   15101018  Comedy     False                   True                en
# 4   15101018  Comedy     False                   True                en
# 5   15101018  Comedy     False                   True                en
# 6   15101018  Comedy     False                   True                en
# 7   15101018  Comedy     False                   True                en
# 8   15101018  Comedy     False                   True                en
# 9   15101018  Comedy     False                   True                en
# 10  15101018  Comedy     False                   True                en
# 11  15101018  Comedy     False                   True                en
# 12  15101018  Comedy     False                   True                en
# 13  15101018  Comedy     False                   True                en
# 14  15101018  Comedy     False                   True                en
# 15  15101018  Comedy     False                   True                en
# 16  15101018  Comedy     False                   True                en
# 17  15101018  Comedy     False                   True                en
# 18  15101018  Comedy     False                   True                en
# 19  15101018  Comedy     False                   True                en
#
#     release_month  production_company        production_country  runtime  \
# 0               2  Paramount Pictures  United States of America       93
# 1               2  Paramount Pictures  United States of America       93
# 2               2  Paramount Pictures  United States of America       93
# 3               2  Paramount Pictures  United States of America       93
# 4               2  Paramount Pictures  United States of America       93
# 5               2  Paramount Pictures  United States of America       93
# 6               2  Paramount Pictures  United States of America       93
# 7               2  Paramount Pictures  United States of America       93
# 8               2  Paramount Pictures  United States of America       93
# 9               2  Paramount Pictures  United States of America       93
# 10              2  Paramount Pictures  United States of America       93
# 11              2  Paramount Pictures  United States of America       93
# 12              2  Paramount Pictures  United States of America       93
# 13              2  Paramount Pictures  United States of America       93
# 14              2  Paramount Pictures  United States of America       93
# 15              2  Paramount Pictures  United States of America       93
# 16              2  Paramount Pictures  United States of America       93
# 17              2  Paramount Pictures  United States of America       93
# 18              2  Paramount Pictures  United States of America       93
# 19              2  Paramount Pictures  United States of America       93
#
#    keyword director actors_itemsets   revenue
# 0    other    other           other  13283126
# 1    other    other           other  13283126
# 2    other    other           other  13283126
# 3    other    other           other  13283126
# 4    other    other           other  13283126
# 5    other    other           other  13283126
# 6    other    other           other  13283126
# 7    other    other           other  13283126
# 8    other    other           other  13283126
# 9    other    other           other  13283126
# 10   other    other           other  13283126
# 11   other    other           other  13283126
# 12   other    other           other  13283126
# 13   other    other           other  13283126
# 14   other    other           other  13283126
# 15   other    other           other  13283126
# 16   other    other           other  13283126
# 17   other    other           other  13283126
# 18   other    other           other  13283126
# 19   other    other           other  13283126

# %%
computatation_dataset = processed_dataset.copy()

# %%
computatation_dataset.drop_duplicates(keep = 'first', inplace = True)
computatation_dataset = computatation_dataset.reset_index(drop=True)
computatation_dataset.shape
# Out:
# (15623, 13)

# %%
computatation_dataset.to_csv('feature_vector.csv', index=False)
computatation_dataset.head(20)
# Out:
#       budget      genre  homepage  belongs_to_collection original_language  \
# 0   15101018     Comedy     False                   True                en
# 1   15101018     Comedy     False                   True                en
# 2   15101018     Comedy     False                   True                en
# 3   15101018     Comedy     False                   True                en
# 4   54135944     Comedy     False                   True                en
# 5   54135944      Drama     False                   True                en
# 6   54135944     Family     False                   True                en
# 7   54135944    Romance     False                   True                en
# 8    3563750      Drama      True                  False                en
# 9    1336221   Thriller      True                  False                hi
# 10   1336221      Drama      True                  False                hi
# 11  18004014  Animation     False                  False                en
# 12  18004014  Adventure     False                  False                en
# 13  18004014     Family     False                  False                en
# 14  15589248     Horror      True                  False                en
# 15  15589248     Horror      True                  False                en
# 16  15589248   Thriller      True                  False                en
# 17  15589248   Thriller      True                  False                en
# 18   8336641     Comedy     False                  False                en
# 19   8336641      Music     False                  False                en
#
#     release_month  production_company        production_country  runtime  \
# 0               2  Paramount Pictures  United States of America       93
# 1               2  Paramount Pictures  United States of America       93
# 2               2               other  United States of America       93
# 3               2               other  United States of America       93
# 4               8               other  United States of America      113
# 5               8               other  United States of America      113
# 6               8               other  United States of America      113
# 7               8               other  United States of America      113
# 8              10               other  United States of America      105
# 9               3               other                     India      122
# 10              3               other                     India      122
# 11              8               other                     other       83
# 12              8               other                     other       83
# 13              8               other                     other       83
# 14              8               other  United States of America       92
# 15              8               other                    Canada       92
# 16              8               other  United States of America       92
# 17              8               other                    Canada       92
# 18              4               other  United States of America       91
# 19              4               other  United States of America       91
#
#                  keyword director actors_itemsets    revenue
# 0                  other    other           other   13283126
# 1   duringcreditsstinger    other           other   13283126
# 2                  other    other           other   13283126
# 3   duringcreditsstinger    other           other   13283126
# 4                  other    other           other  128775114
# 5                  other    other           other  128775114
# 6                  other    other           other  128775114
# 7                  other    other           other  128775114
# 8                  other    other           other   14138371
# 9                  other    other           other   17816284
# 10                 other    other           other   17816284
# 11                 other    other           other    7340322
# 12                 other    other           other    7340322
# 13                 other    other           other    7340322
# 14                 other    other           other   95145723
# 15                 other    other           other   95145723
# 16                 other    other           other   95145723
# 17                 other    other           other   95145723
# 18                 other    other           other   26052345
# 19                 other    other           other   26052345
